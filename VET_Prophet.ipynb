# %% [markdown]
# <a href="https://colab.research.google.com/github/CRag-01/Crypto-Token-Analysis---Vizualisation/blob/main/VET_Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# import yfinance as yf
from datetime import datetime
from datetime import timedelta
import plotly.graph_objects as go
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly

# %%
import warnings

# %%
pip install yfinance

# %%
import yfinance as yf

# %%
warnings.filterwarnings('ignore')
pd.options.display.float_format = '₹{:,.5f}'.format

# %%
today = datetime.today().strftime('%Y-%m-%d')
start_date = '2016-01-01'
eth_df = yf.download('VET-INR',start_date, today)
eth_df.to_csv("VET.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
eth_df.head()
# Out:
#                Open     High      Low    Close  Adj Close      Volume
# Date
# 2019-09-18 ₹0.30258 ₹0.31462 ₹0.29994 ₹0.30622   ₹0.30622  2325069043
# 2019-09-19 ₹0.30627 ₹0.30717 ₹0.28882 ₹0.30107   ₹0.30107  2122528617
# 2019-09-20 ₹0.30120 ₹0.30429 ₹0.29527 ₹0.29853   ₹0.29853  1959609443
# 2019-09-21 ₹0.29847 ₹0.30371 ₹0.29439 ₹0.29551   ₹0.29551  2599520867
# 2019-09-22 ₹0.29562 ₹0.29602 ₹0.28611 ₹0.28914   ₹0.28914  2197349727

# %%
eth_df.tail()
# Out:
#                Open     High      Low    Close  Adj Close       Volume
# Date
# 2021-12-03 ₹8.68997 ₹8.98404 ₹7.93009 ₹8.19201   ₹8.19201  37991853437
# 2021-12-04 ₹8.20855 ₹8.21095 ₹5.33741 ₹7.27511   ₹7.27511  70362270142
# 2021-12-05 ₹7.26492 ₹7.38198 ₹6.50911 ₹6.75189   ₹6.75189  34984397541
# 2021-12-06 ₹6.75745 ₹7.07317 ₹5.99758 ₹7.06625   ₹7.06625  45334547172
# 2021-12-07 ₹7.10790 ₹7.14542 ₹6.99242 ₹7.08021   ₹7.08021  44477095936

# %%
eth_df.reset_index(inplace=True)
eth_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df = eth_df[["Date", "Open"]]
new_names = {
    "Date": "ds", 
    "Open": "y",
}
df.rename(columns=new_names, inplace=True)

# %%
df.tail()
# Out:
#             ds        y
# 800 2021-12-03 ₹8.68997
# 801 2021-12-04 ₹8.20855
# 802 2021-12-05 ₹7.26492
# 803 2021-12-06 ₹6.75745
# 804 2021-12-07 ₹7.10790

# %%
# Visualisation of the price trend
x = df["ds"]
y = df["y"]
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y))
# Set title
fig.update_layout(
    title_text="Time Series Plot of the VET-INR Price",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2c966a61-948c-4bc3-82a6-40321d02d77d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2c966a61-948c-4bc3-82a6-40321d02d77d")) {
#                     Plotly.newPlot(
#                         '2c966a61-948c-4bc3-82a6-40321d02d77d',
# ...

# %%
m = Prophet(
    seasonality_mode="multiplicative" 
)
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods = 365)
future.tail()
# Out:
#              ds
# 1165 2022-12-03
# 1166 2022-12-04
# 1167 2022-12-05
# 1168 2022-12-06
# 1169 2022-12-07

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 1165 2022-12-03 ₹15.19617   ₹13.53806   ₹16.76796
# 1166 2022-12-04 ₹14.72006   ₹13.07822   ₹16.32229
# 1167 2022-12-05 ₹14.52012   ₹12.89713   ₹16.06318
# 1168 2022-12-06 ₹14.04786   ₹12.57248   ₹15.53682
# 1169 2022-12-07 ₹13.58019   ₹11.99259   ₹14.96865

# %%
plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4530551-4e5b-4d99-9d08-3a6cda333fac" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4530551-4e5b-4d99-9d08-3a6cda333fac")) {
#                     Plotly.newPlot(
#                         'f4530551-4e5b-4d99-9d08-3a6cda333fac',
# ...

# %%
next_day = (datetime.today() + timedelta(days=1)).strftime('%Y-%m-%d')
print(f" PREDICTED Opening Price of VET tomorrow: {forecast[forecast['ds'] == next_day]['yhat'].item()}")
# Out:
#  PREDICTED Opening Price of VET tomorrow: 7.062622635197842

# %%
plot_components_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9f262d42-529f-43ee-af6b-34bffdb7383a" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f262d42-529f-43ee-af6b-34bffdb7383a")) {
#                     Plotly.newPlot(
#                         '9f262d42-529f-43ee-af6b-34bffdb7383a',
# ...
