# %% [markdown]
# <a href="https://colab.research.google.com/github/CRag-01/Crypto-Token-Analysis---Vizualisation/blob/main/XRP_Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# import yfinance as yf
from datetime import datetime
from datetime import timedelta
import plotly.graph_objects as go
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly

# %%
import warnings

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 7.3 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf

# %%
warnings.filterwarnings('ignore')
pd.options.display.float_format = '₹{:,.5f}'.format

# %%
today = datetime.today().strftime('%Y-%m-%d')
start_date = '2016-01-01'
eth_df = yf.download('XRP-INR',start_date, today)
eth_df.to_csv("XRP.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
eth_df.head()
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2019-09-18 ₹20.38026 ₹22.92393 ₹20.21088 ₹22.33613  ₹22.33613  181413150577
# 2019-09-19 ₹22.33357 ₹22.40413 ₹20.49346 ₹21.59223  ₹21.59223  165230518912
# 2019-09-20 ₹21.59320 ₹21.53661 ₹20.55923 ₹20.96804  ₹20.96804  110943887249
# 2019-09-21 ₹20.96705 ₹21.18900 ₹20.49127 ₹20.61004  ₹20.61004   90201714980
# 2019-09-22 ₹20.61127 ₹20.62491 ₹19.53148 ₹19.86004  ₹19.86004   88451349767

# %%
eth_df.tail()
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2021-12-03 ₹72.99065 ₹74.04626 ₹68.18193 ₹69.46188  ₹69.46188  204460114673
# 2021-12-04 ₹69.60110 ₹69.79482 ₹46.28348 ₹63.71989  ₹63.71989  524396287743
# 2021-12-05 ₹63.69579 ₹64.97963 ₹58.70753 ₹60.61836  ₹60.61836  267387695108
# 2021-12-06 ₹60.65240 ₹62.71649 ₹56.72454 ₹62.44592  ₹62.44592  259946515357
# 2021-12-07 ₹62.60822 ₹63.55998 ₹62.17281 ₹62.86063  ₹62.86063  259013165056

# %%
eth_df.reset_index(inplace=True)
eth_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df = eth_df[["Date", "Open"]]
new_names = {
    "Date": "ds", 
    "Open": "y",
}
df.rename(columns=new_names, inplace=True)

# %%
df.tail()
# Out:
#             ds         y
# 803 2021-12-03 ₹72.99065
# 804 2021-12-04 ₹69.60110
# 805 2021-12-05 ₹63.69579
# 806 2021-12-06 ₹60.65240
# 807 2021-12-07 ₹62.60822

# %%
# Visualisation of the price trend
x = df["ds"]
y = df["y"]
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y))
# Set title
fig.update_layout(
    title_text="Time Series Plot of the XRP-INR Price",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="06cada6c-c425-46f8-b51e-1c6143118a35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06cada6c-c425-46f8-b51e-1c6143118a35")) {
#                     Plotly.newPlot(
#                         '06cada6c-c425-46f8-b51e-1c6143118a35',
# ...

# %%
m = Prophet(
    seasonality_mode="multiplicative" 
)
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods = 365)
future.tail()
# Out:
#              ds
# 1168 2022-12-03
# 1169 2022-12-04
# 1170 2022-12-05
# 1171 2022-12-06
# 1172 2022-12-07

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1168 2022-12-03 ₹129.53729  ₹115.29469  ₹145.12588
# 1169 2022-12-04 ₹131.22898  ₹116.41562  ₹147.12179
# 1170 2022-12-05 ₹131.39102  ₹115.90692  ₹146.29978
# 1171 2022-12-06 ₹133.04715  ₹117.49409  ₹147.07053
# 1172 2022-12-07 ₹134.51184  ₹119.77780  ₹149.89638

# %%
plot_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2910c006-bae8-4c4f-a510-3b19b140dd81" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2910c006-bae8-4c4f-a510-3b19b140dd81")) {
#                     Plotly.newPlot(
#                         '2910c006-bae8-4c4f-a510-3b19b140dd81',
# ...

# %%
next_day = (datetime.today() + timedelta(days=1)).strftime('%Y-%m-%d')
print(f" PREDICTED Opening Price of XRP tomorrow: {forecast[forecast['ds'] == next_day]['yhat'].item()}")
# Out:
#  PREDICTED Opening Price of XRP tomorrow: 82.62135458815581

# %%
plot_components_plotly(m, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2a8818ce-d227-4f7e-a24e-fadd1bf542c6" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a8818ce-d227-4f7e-a24e-fadd1bf542c6")) {
#                     Plotly.newPlot(
#                         '2a8818ce-d227-4f7e-a24e-fadd1bf542c6',
# ...
